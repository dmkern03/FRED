# %%
# %sql
-- Load rates data
COPY INTO investments.fred.bronze_rates
FROM '/Volumes/investments/fred/rates/'
FILEFORMAT = CSV
PATTERN = 'fred_rates_historical_*.csv'
FORMAT_OPTIONS (
    'header' = 'true',
    'inferSchema' = 'true'
)

# %%
# %sql
COPY INTO investments.fred.bronze_metadata
FROM '/Volumes/investments/fred/metadata/'
FILEFORMAT = JSON
PATTERN = 'fred_series_metadata_*.json';
